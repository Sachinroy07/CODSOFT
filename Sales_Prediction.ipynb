# %% [markdown]
# <a href="https://colab.research.google.com/github/Sachinroy07/CODSOFT/blob/main/Sales_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***`> TASK-4 : SALES PREDICTION USING PYTHON`***
#
#
#
# > Author: Sachin Kumar
#
#
#
# > Batch : February
#
#
#
# > Domin : Data Science

# %% [markdown]
# ***IMPORTING IMPORTANT LIBRARIES***

# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# Import the numpy and pandas package

import numpy as np
import pandas as pd

# Data Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data =pd.read_csv("/content/drive/MyDrive/advertising (1).csv")
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['TV'].plot(kind='hist', bins=20, title='TV')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Radio'].plot(kind='hist', bins=20, title='Radio')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Newspaper'].plot(kind='hist', bins=20, title='Newspaper')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Sales'].plot(kind='hist', bins=20, title='Sales')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %% [markdown]
# *Aim: Sales Prediction involves forecasting the amount of a profduct that customers will purchase, taking into account Various factor such as adverrtising expenditure, target audience segmentation, and advertising platform Selection.*

# %% [markdown]
# >Given dataset consist of the advertising platform and the releted sales. Let's visulalize each platform

# %%
data.shape
# Out:
# (200, 4)

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['TV'].plot(kind='hist', bins=20, title='TV')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['Radio'].plot(kind='hist', bins=20, title='Radio')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
x = data.iloc[:,0:-1]

# %%
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x['TV'].plot(kind='hist', bins=20, title='TV')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x['Radio'].plot(kind='hist', bins=20, title='Radio')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x['Newspaper'].plot(kind='hist', bins=20, title='Newspaper')
# ...

# %%
data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_22['TV'].plot(kind='hist', bins=20, title='TV')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23['Radio'].plot(kind='hist', bins=20, title='Radio')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['Newspaper'].plot(kind='hist', bins=20, title='Newspaper')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25['Sales'].plot(kind='hist', bins=20, title='Sales')
# ...

# %% [markdown]
# **BASIC OBSERVATION**
#
# > Avg expense spend is highest on TV
#
#
# > Avg expend spend is lowest on Radio
#
# > max sale is 27 & min is 1.6

# %%
import seaborn as sns
sns.pairplot(data=data)
plt.show()

# %% [markdown]
# Pair Plot Observation
#
# ---
#
# When advertising cost increases in TV Ads the sales will increase as well. While the for newspaper and radio it is bit unpredictable.

# %%
data['TV'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['Radio'].plot.hist(bins=20, color="purple", xlabel="Radio")
plt.show()

# %%
data['Newspaper'].plot.hist(bins=20, color="green", xlabel="newspaper")
plt.show()

# %% [markdown]
# **`OBSERVATION`**
#
# ---
#  The majority sales is the result of low advertising cost in newspaper.

# %%
sns.heatmap(data.corr(),annot = True)
plt.show()

# %%
# Distribution of the variables
sns.boxplot(data.melt(value_vars=data.columns), x='variable', y='value')
plt.title('Distribution of continuons variables')
plt.xlabel('variables')
plt.ylabel('values')
# Out:
# Text(0, 0.5, 'values')

# %% [markdown]
# **SALES IS HIGHLY COORELATED WITH THE TV**
#
# Lets train our model using linear regression as it is coorelated with only one variable TV

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['TV']],data[['Sales']], test_size=0.2,random_state=43)

# %%
print (f'''x Train: {x_train.shape}
  x Test: {x_test.shape}
  y Train: {y_train.shape}
  y Test: {y_test.shape}''')
# Out:
# x Train: (160, 1)
#   x Test: (40, 1)
#   y Train: (160, 1)
#   y Test: (40, 1)

# %%
x_train
# Out:
#         TV
# 116  139.2
# 138   43.0
# 155    4.1
# 82    75.3
# 160  172.5
# ..     ...
# 58   210.8
# 21   237.4
# 49    66.9
# 64   131.1
# 68   237.4
#
# [160 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_44['TV'].plot(kind='hist', bins=20, title='TV')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_45['TV'].plot(kind='line', figsize=(8, 4), title='TV')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
x_test
# Out:
#         TV
# 56     7.3
# 37    74.7
# 67   139.3
# 79   116.0
# 80    76.4
# 188  286.0
# 183  287.6
# 10    66.1
# 128  220.3
# 62   239.3
# 65    69.0
# 17   281.4
# 133  219.8
# 195   38.2
# 146  240.1
# 38    43.1
# 173  168.4
# 149   44.7
# 93   250.9
# 29    70.6
# 0    230.1
# 2     17.2
# 122  224.0
# 180  156.6
# 95   163.3
# 121   18.8
# 185  205.0
# 39   228.0
# 66    31.5
# 19   147.3
# 11   214.7
# 45   175.1
# 41   177.0
# 92   217.7
# 168  215.4
# 1     44.5
# 57   136.2
# 189   18.7
# 151  121.0
# 167  206.8
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_42['TV'].plot(kind='hist', bins=20, title='TV')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
y_train
# Out:
#      Sales
# 116   12.2
# 138    9.6
# 155    3.2
# 82    11.3
# 160   16.4
# ..     ...
# 58    23.8
# 21    17.5
# 49     9.7
# 64    16.0
# 68    18.9
#
# [160 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_40['Sales'].plot(kind='hist', bins=20, title='Sales')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_41['Sales'].plot(kind='line', figsize=(8, 4), title='Sales')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
y_test
# Out:
#      Sales
# 56     5.5
# 37    14.7
# 67    13.4
# 79    11.0
# 80    11.8
# 188   20.9
# 183   26.2
# 10    12.6
# 128   24.7
# 62    20.7
# 65    11.3
# 17    24.4
# 133   19.6
# 195    7.6
# 146   18.2
# 38    10.1
# 173   16.7
# 149   10.1
# 93    22.2
# 29    10.5
# 0     22.1
# 2     12.0
# 122   16.6
# 180   15.5
# 95    16.9
# 121    7.0
# 185   22.6
# 39    21.5
# 66    11.0
# 19    14.6
# 11    17.4
# 45    16.1
# 41    17.1
# 92    19.4
# 168   17.1
# 1     10.4
# 57    13.2
# 189    6.7
# 151   11.6
# 167   17.2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_38['Sales'].plot(kind='hist', bins=20, title='Sales')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
x_train =x_train.astype(int)
x_test= x_test.astype(int)
y_train= y_train.astype(int)
y_test= y_test.astype(int)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
x_train_scaled = sc.fit_transform(x_train)
x_test_scaled = sc.fit_transform(x_test)

# %% [markdown]
# ♦ ***Linear Regression***

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test
# Out:
#      Sales
# 56       5
# 37      14
# 67      13
# 79      11
# 80      11
# 188     20
# 183     26
# 10      12
# 128     24
# 62      20
# 65      11
# 17      24
# 133     19
# 195      7
# 146     18
# 38      10
# 173     16
# 149     10
# 93      22
# 29      10
# 0       22
# 2       12
# 122     16
# 180     15
# 95      16
# 121      7
# 185     22
# 39      21
# 66      11
# 19      14
# 11      17
# 45      16
# 41      17
# 92      19
# 168     17
# 1       10
# 57      13
# 189      6
# 151     11
# 167     17
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# y_test['Sales'].plot(kind='hist', bins=20, title='Sales')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
plt.plot(res)

# %%
import matplotlib.pyplot as plt

plt.scatter(x_test, y_test)
plt.plot(y_test, 7.14382225+ 0.05473199* y_test, 'b')
plt.scatter(x_test, x_test, c='b', label='Predicted', marker='o')
plt.scatter(x_test, x_test, c='r', label='True', marker='o')
plt.xlabel('True values')
plt.ylabel('Predicted values')
plt.title('True vs. Predicted values')
plt.legend()
plt.show()

# %% [markdown]
# ***PREDICTION***

# %% [markdown]
# **Concluding with saying that above mention solution is successfully able to predict the sales using advertising platform datasets.**
